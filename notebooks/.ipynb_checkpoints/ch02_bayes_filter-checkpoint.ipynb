# %% [markdown]
# # Chapter 2 — Recursive State Estimation: Discrete Bayes Filter
#
# **Formula to internalize:**
# - **Prediction** = push uncertainty *through* the motion model (convolution)
# - **Correction** = keep states that *explain the measurement* better (reweighting)
#
# When you can say that sentence fluently, the formula lives.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../src'))

import numpy as np
import matplotlib.pyplot as plt
from pluto_filters.pluto_filters.bayes_filter.discrete_bayes_filter import (
    DiscreteBayesFilter1D, CELL_CENTERS, DOOR_POSITIONS, N_CELLS
)

def entropy(b):
    b = np.clip(b, 1e-300, 1)
    return -np.sum(b * np.log(b))

# %%
# ── Original demo: 3 peaks → 1 peak ────────────────────────────────────────
bf = DiscreteBayesFilter1D()
history, events = [], []

def record(ev):
    history.append(bf.belief.copy())
    events.append(ev)

record('prior (uniform)')
bf.update(True);   record('sense door → 3 peaks')
bf.predict(3.0);   record('move +3m → peaks shift')
bf.update(True);   record('sense door → 2 peaks')
bf.predict(3.0);   record('move +3m')
bf.update(True);   record('sense door → 1 peak (localized!)')

fig, axes = plt.subplots(len(history), 1, figsize=(12, 2.5 * len(history)))
fig.suptitle("Discrete Bayes Filter — Pluto's Belief Over Time", fontsize=13)
for i, (belief, ev) in enumerate(zip(history, events)):
    ax = axes[i]
    ax.bar(CELL_CENTERS, belief, width=0.09, color='steelblue', alpha=0.8)
    for d in DOOR_POSITIONS:
        ax.axvline(d, color='brown', ls='--', alpha=0.6)
    ax.set_xlim(0, 10); ax.set_ylim(0, belief.max()*1.3+1e-5)
    ax.set_ylabel('p(x)')
    ax.set_title(f'Step {i}: {ev}  [H={entropy(belief):.3f} nats]')
    if i == len(history)-1: ax.set_xlabel('Position [m]')
plt.tight_layout(); plt.savefig('ch02_bayes_filter.png', dpi=120); plt.show()
print(f"Final mode: x = {CELL_CENTERS[np.argmax(bf.belief)]:.2f} m")

# %% [markdown]
# ## Exercise 1 — Negative Evidence: Sense NO Door
#
# > "What happens when the sensor says NO door?"
# > Negative evidence is often *more informative* than expected.

# %%
# EXERCISE 1: negative evidence — sense NO door
bf_neg = DiscreteBayesFilter1D()
neg_history, neg_events = [], []

def rneg(ev):
    neg_history.append(bf_neg.belief.copy())
    neg_events.append(ev)

rneg('prior (uniform)')
bf_neg.update(False);  rneg('sense NO door → anti-peaks at doors')
bf_neg.predict(1.5);   rneg('move +1.5m')
bf_neg.update(True);   rneg('sense door (now informative!)')
bf_neg.predict(3.0);   rneg('move +3m')
bf_neg.update(True);   rneg('sense door → localized')

fig, axes = plt.subplots(len(neg_history), 1, figsize=(12, 2.3 * len(neg_history)))
fig.suptitle('Negative Evidence: Sense NO door first, then sense door', fontsize=12)
for i, (belief, ev) in enumerate(zip(neg_history, neg_events)):
    ax = axes[i]
    ax.bar(CELL_CENTERS, belief, width=0.09, color='darkorange', alpha=0.8)
    for d in DOOR_POSITIONS:
        ax.axvline(d, color='brown', ls='--', alpha=0.5)
    ax.set_xlim(0,10); ax.set_ylim(0, belief.max()*1.3+1e-5)
    ax.set_ylabel('p(x)')
    ax.set_title(f'Step {i}: {ev}  [H={entropy(belief):.3f}]')
    if i == len(neg_history)-1: ax.set_xlabel('Position [m]')
plt.tight_layout(); plt.show()
print("Key insight: after sensing NO door, probability DROPS near all 3 door positions.")
print("Negative evidence eliminates hypotheses — often more powerfully than positive evidence.")

# %% [markdown]
# ## Exercise 2 — Prediction as Convolution
#
# > Visualize **prediction = convolution** of current belief with the motion kernel.
# > The kernel is a Gaussian; wider kernel = more uncertain motion.

# %%
# EXERCISE 2: visualize prediction as convolution
from scipy.ndimage import gaussian_filter1d

sigma_cells = 0.5 / 0.1  # 0.5m / 0.1m per cell
belief_before = history[1].copy()  # 3-peak belief
belief_after  = gaussian_filter1d(belief_before, sigma=sigma_cells, mode='wrap')
belief_after  = np.roll(belief_after, int(3.0 / 0.1))  # shift 3m
belief_after /= belief_after.sum()

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
fig.suptitle('Prediction = Convolution with Motion Kernel', fontsize=13)

axes[0].bar(CELL_CENTERS, belief_before, width=0.09, color='steelblue', alpha=0.8)
axes[0].set_title('Before predict: belief p(x)'); axes[0].set_xlim(0,10); axes[0].set_ylabel('p(x)')

kernel_x = np.linspace(-2, 2, 100)
kernel_y = np.exp(-kernel_x**2 / (2 * 0.5**2)); kernel_y /= kernel_y.sum()
axes[1].fill_between(kernel_x, kernel_y, alpha=0.7, color='green')
axes[1].set_title(f'Motion kernel (σ=0.5m)  ★  (convolution)'); axes[1].set_xlabel('Δx [m]')

axes[2].bar(CELL_CENTERS, belief_after, width=0.09, color='coral', alpha=0.8)
axes[2].set_title('After predict: belief spreads + shifts'); axes[2].set_xlim(0,10)
for ax in axes: ax.set_xlabel('Position [m]') if ax != axes[1] else None
plt.tight_layout(); plt.show()
print("Convolution SPREADS peaks (increases uncertainty) and SHIFTS them (applies motion).")

# %% [markdown]
# ## Exercise 3 — Wrong Map: Confident but Wrong
#
# > Give the filter the wrong door positions and watch how confident it becomes — in the wrong answer.

# %%
# EXERCISE 3: wrong map — door at x=3,6,9 instead of 2,5,8
class WrongMapFilter(DiscreteBayesFilter1D):
    def __init__(self):
        super().__init__()
        self._door_positions_wrong = [3.0, 6.0, 9.0]

    def update(self, door_detected):
        # Override measurement model to use wrong door positions
        likelihood = np.ones(N_CELLS) * 0.15  # false alarm baseline
        for d in self._door_positions_wrong:
            idx = int(d / 0.1)
            r = 5
            likelihood[max(0, idx-r):min(N_CELLS, idx+r)] = 0.85
        if not door_detected:
            likelihood = 1.0 - likelihood
        self.belief *= likelihood
        s = self.belief.sum()
        if s > 0:
            self.belief /= s

wrong_bf = WrongMapFilter()
wrong_bf.update(True);   w1 = wrong_bf.belief.copy()
wrong_bf.predict(3.0);   w2 = wrong_bf.belief.copy()
wrong_bf.update(True);   w3 = wrong_bf.belief.copy()

correct_final = history[-1]  # from the original correct demo

fig, axes = plt.subplots(1, 2, figsize=(14, 4))
fig.suptitle('Wrong Map: Confident in the WRONG Answer', fontsize=13)

ax = axes[0]
ax.bar(CELL_CENTERS, correct_final, width=0.09, color='steelblue', alpha=0.8)
for d in DOOR_POSITIONS: ax.axvline(d, color='brown', ls='--', alpha=0.6, label='true door')
ax.set_title(f'Correct map — peak at x={CELL_CENTERS[np.argmax(correct_final)]:.1f}m'); ax.set_xlim(0,10)
ax.legend(fontsize=8); ax.set_xlabel('Position [m]'); ax.set_ylabel('p(x)')

ax = axes[1]
ax.bar(CELL_CENTERS, w3, width=0.09, color='crimson', alpha=0.8)
for d in [3.0, 6.0, 9.0]: ax.axvline(d, color='green', ls='--', alpha=0.6, label='wrong door')
for d in DOOR_POSITIONS: ax.axvline(d, color='brown', ls=':', alpha=0.4, label='true door')
ax.set_title(f'Wrong map — peak at x={CELL_CENTERS[np.argmax(w3)]:.1f}m  ← WRONG!'); ax.set_xlim(0,10)
ax.legend(fontsize=7); ax.set_xlabel('Position [m]')

plt.tight_layout(); plt.show()
print("The filter is just as CONFIDENT with the wrong map as with the correct one.")
print("This is why map quality matters: garbage in → confident garbage out.")

# %% [markdown]
# ## Exercise 4 — Sensor Reliability Sweep

# %%
# EXERCISE 4: sweep P_HIT_DOOR from near-perfect to random
p_hits = [0.95, 0.75, 0.60, 0.50]
colors = ['green', 'steelblue', 'orange', 'crimson']

fig, axes = plt.subplots(1, len(p_hits), figsize=(15, 4))
fig.suptitle('Sensor Reliability Sweep — After 3 door observations', fontsize=13)

for ax, p_hit, col in zip(axes, p_hits, colors):
    class SweepFilter(DiscreteBayesFilter1D):
        def __init__(self, p):
            super().__init__(); self._p_hit = p
        def update(self, door_detected):
            likelihood = np.ones(N_CELLS) * (1 - self._p_hit)
            for d in DOOR_POSITIONS:
                idx = int(d / 0.1); r = 5
                likelihood[max(0, idx-r):min(N_CELLS, idx+r)] = self._p_hit
            if not door_detected:
                likelihood = 1.0 - likelihood
            self.belief *= likelihood
            s = self.belief.sum()
            if s > 0: self.belief /= s

    sf = SweepFilter(p_hit)
    sf.update(True); sf.predict(3.0); sf.update(True); sf.predict(3.0); sf.update(True)
    H = entropy(sf.belief)
    ax.bar(CELL_CENTERS, sf.belief, width=0.09, color=col, alpha=0.8)
    for d in DOOR_POSITIONS: ax.axvline(d, color='brown', ls='--', alpha=0.5)
    ax.set_xlim(0,10); ax.set_title(f'p_hit={p_hit}\nH={H:.3f}')
    ax.set_xlabel('x [m]'); ax.set_ylabel('p(x)' if ax == axes[0] else '')

plt.tight_layout(); plt.show()
print("p_hit=0.50 = random sensor: belief stays nearly uniform (high entropy).")
print("Sensor quality directly controls localization precision.")

# %% [markdown]
# ## Exercise 5 — Entropy Over Time: When Is Localization Good Enough?

# %%
# EXERCISE 5: entropy trajectory — when is the robot localized enough to act?
bf5 = DiscreteBayesFilter1D()
ent_log, step_labels = [entropy(bf5.belief)], ['start']

bf5.update(True);   ent_log.append(entropy(bf5.belief)); step_labels.append('sense door')
bf5.predict(0.5);   ent_log.append(entropy(bf5.belief)); step_labels.append('move 0.5m')
bf5.predict(0.5);   ent_log.append(entropy(bf5.belief)); step_labels.append('move 0.5m')
bf5.predict(0.5);   ent_log.append(entropy(bf5.belief)); step_labels.append('move 0.5m')
bf5.predict(0.5);   ent_log.append(entropy(bf5.belief)); step_labels.append('move 0.5m')
bf5.predict(0.5);   ent_log.append(entropy(bf5.belief)); step_labels.append('move 0.5m')
bf5.update(True);   ent_log.append(entropy(bf5.belief)); step_labels.append('sense door')
bf5.predict(1.0);   ent_log.append(entropy(bf5.belief)); step_labels.append('move 1m')
bf5.update(False);  ent_log.append(entropy(bf5.belief)); step_labels.append('sense NO door')
bf5.predict(1.0);   ent_log.append(entropy(bf5.belief)); step_labels.append('move 1m')
bf5.update(True);   ent_log.append(entropy(bf5.belief)); step_labels.append('sense door')

THRESHOLD_NATS = 0.5  # below this → localized enough to act
fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(ent_log, 'b-o', lw=2, ms=6)
ax.axhline(THRESHOLD_NATS, color='red', ls='--', lw=1.5, label=f'Action threshold ({THRESHOLD_NATS} nats)')
ax.axhline(np.log(N_CELLS), color='gray', ls=':', lw=1.5, label=f'Max entropy (uniform) = {np.log(N_CELLS):.2f}')
for i, lbl in enumerate(step_labels):
    ax.annotate(lbl, (i, ent_log[i] + 0.02), rotation=45, ha='left', fontsize=7)
ax.set_xlabel('Step index'); ax.set_ylabel('Entropy [nats]')
ax.set_title('Entropy over time — when is localization good enough to act?')
ax.legend(fontsize=9)
plt.tight_layout(); plt.show()
first_below = next((i for i, h in enumerate(ent_log) if h < THRESHOLD_NATS), None)
print(f"First step below threshold {THRESHOLD_NATS} nats: step {first_below} ({step_labels[first_below]})")

# %% [markdown]
# ## ✅ Compare | 🔥 Break | 📏 Measure

# %%
# COMPARE: correct map vs wrong map — entropy at convergence
print("=== COMPARE: Correct vs Wrong map ===")
print(f"Correct map final entropy: {entropy(history[-1]):.4f} nats")
print(f"Wrong map final entropy  : {entropy(w3):.4f} nats")
print(f"(lower entropy = more confident; neither can self-detect the mistake)\n")

# BREAK: what if there are 5 identical doors instead of 3?
print("=== BREAK: 5 doors instead of 3 ===")
class FiveDoorFilter(DiscreteBayesFilter1D):
    def update(self, door_detected):
        five_doors = [1.5, 3.0, 4.5, 6.5, 8.5]
        likelihood = np.ones(N_CELLS) * 0.15
        for d in five_doors:
            idx = int(d / 0.1); r = 4
            likelihood[max(0,idx-r):min(N_CELLS,idx+r)] = 0.85
        if not door_detected: likelihood = 1.0 - likelihood
        self.belief *= likelihood
        s = self.belief.sum()
        if s > 0: self.belief /= s

fd = FiveDoorFilter()
fd.update(True); fd.predict(3.0); fd.update(True); fd.predict(3.0); fd.update(True)
print(f"5-door final entropy: {entropy(fd.belief):.4f} nats  (higher = harder to localize)\n")

# MEASURE
print("=== MEASURE: steps to reach H < 0.5 nats ===")
for p_hit in [0.95, 0.75, 0.60]:
    class M(DiscreteBayesFilter1D):
        def update(self, d):
            L = np.ones(N_CELLS)*(1-p_hit)
            for dp in DOOR_POSITIONS:
                idx=int(dp/0.1); r=5; L[max(0,idx-r):min(N_CELLS,idx+r)]=p_hit
            if not d: L=1-L
            self.belief*=L; s=self.belief.sum()
            if s>0: self.belief/=s
    mf=M()
    for step in range(1, 50):
        if step % 2 == 1: mf.update(True)
        else: mf.predict(3.0)
        if entropy(mf.belief) < 0.5:
            print(f"  p_hit={p_hit}: localized at step {step}"); break
    else:
        print(f"  p_hit={p_hit}: NOT localized in 50 steps")
